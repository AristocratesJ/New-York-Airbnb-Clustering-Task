# %% [markdown]
# # Wczytanie danych oraz bibliotek

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import random
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("../data/to_model/new_york_listings_2024_to_model.csv");
data.head()
# Out:
#                    id                                               name  \
# 0  718037328155265207  Rental unit in Queens · 5 bedrooms · 8 beds · ...
# 1             5536638  Rental unit in Brooklyn · ★4.60 · 2 bedrooms ·...
# 2             4605840  Rental unit in Brooklyn · ★4.93 · 1 bedroom · ...
# 3  594240338554500815  Rental unit in New York · 1 bedroom · 1 bed · ...
# 4               26785  Rental unit in Brooklyn · ★4.93 · 1 bedroom · ...
#
#      host_id      host_name neighbourhood_group       neighbourhood  latitude  \
# 0     204539           Mark              Queens           Ridgewood  40.70262
# 1   28709982          Sidiq            Brooklyn        Williamsburg  40.72027
# 2   23788242        Suzanne            Brooklyn  Bedford-Stuyvesant  40.68670
# 3  384559808  Best Inns USA           Manhattan        East Village  40.73221
# 4      42273           Dani            Brooklyn         South Slope  40.66860
#
#    longitude        room_type  price  ...  last_review  reviews_per_month  \
# 0  -73.89800  Entire home/apt  471.0  ...   2022-11-03               0.07
# 1  -73.95513  Entire home/apt  225.0  ...   2023-09-13               0.49
# 2  -73.94856     Private room   80.0  ...   2023-11-17               1.00
# 3  -73.98689  Entire home/apt   83.0  ...   2023-08-11               0.12
# 4  -73.98723  Entire home/apt   90.0  ...   2022-05-31               2.90
#
#   calculated_host_listings_count  availability_365  number_of_reviews_ltm  \
# 0                              9               365                      0
# 1                              5                90                      7
# 2                              2               363                     12
# 3                             30               106                      1
# 4                              3               188                      0
#
#       license     rating bedrooms beds baths
# 0  No License  No rating        5    8     2
# 1  No License      4.60         2    2     1
# 2  No License      4.93         1    1     1
# 3  No License  No rating        1    1     1
# 4  No License      4.93         1    1     1
#
# [5 rows x 22 columns]

# %% [markdown]
# # Przygotowanie danych
# - usuwamy kolumny: id, host_id, host_name, name, neighbourhood_group, neighbourhood, number_of_reviews_ltm (zostawiamy rewievs_per_month), bedrooms (zostawiamy beds)
# - mapujemy kolumnę
#         - 'license' na 0 i 1 (0 - brak licencji, 1 - licencja)
#         - 'baths' na int (jeśli nie jest podana to 0)
#         - 'bedrooms' na int (jeśli nie jest podana to 0, a jeśli jest studio to 1)
#         - 'rating' na float (jeśli nie ma to NaN)
# - ordinal encoding dla 'room_type'
# - kodujmey date 'last_review'
# - uzywamy regresji linowej zeby uzupelnic NA w ratingu

# %% [markdown]
# ### mapujemy

# %%
def lic_mapper(a):
    if a == "No License" or a == "Exempt":
        return 0
    else:
        return 1

def bath_mapper(a):
    if a == "Not specified":
        return 0
    else:
        return int(float(a))
def bedroom_mapper(a): # Uznałem, że posiadanie studio (czyli całe mieszkanie w jednym większym pokoju) to tak jakby była jedna sypialnia
    if a == "Studio":
        return 1
    else:
        return int(a)
def rating_mapper(a): # na razie tak może zostać
    if a == "New " or a == "No rating":
        return np.nan
    else:
        return float(a)
data["license"] = data["license"].map(lic_mapper)  # Jeśli ma licencję to 1, jeśli nie to 0
data["baths"] = data["baths"].map(bath_mapper)
data["bedrooms"] = data["bedrooms"].map(bedroom_mapper)
data["rating"] = data["rating"].map(rating_mapper)
data["last_review"] =  data["last_review"].map(np.datetime64) # Zmapowałem też date ostatniej opinii do przeznaczonego do tego typu

data
# Out:
#                        id                                               name  \
# 0      718037328155265207  Rental unit in Queens · 5 bedrooms · 8 beds · ...
# 1                 5536638  Rental unit in Brooklyn · ★4.60 · 2 bedrooms ·...
# 2                 4605840  Rental unit in Brooklyn · ★4.93 · 1 bedroom · ...
# 3      594240338554500815  Rental unit in New York · 1 bedroom · 1 bed · ...
# 4                   26785  Rental unit in Brooklyn · ★4.93 · 1 bedroom · ...
# ...                   ...                                                ...
# 16601  726891322486149349  Condo in Brooklyn · ★4.87 · 3 bedrooms · 3 bed...
# 16602            51828187  Home in Queens · ★4.69 · 1 bedroom · 1 bed · 1...
# 16603  746852890077275772  Rental unit in The Bronx · ★4.73 · 1 bedroom ·...
# 16604            14822309  Rental unit in New York · ★4.84 · 1 bedroom · ...
# 16605  800437249525223935  Rental unit in New York · 1 bedroom · 1 bed · ...
#
#          host_id      host_name neighbourhood_group       neighbourhood  \
# 0         204539           Mark              Queens           Ridgewood
# 1       28709982          Sidiq            Brooklyn        Williamsburg
# 2       23788242        Suzanne            Brooklyn  Bedford-Stuyvesant
# 3      384559808  Best Inns USA           Manhattan        East Village
# 4          42273           Dani            Brooklyn         South Slope
# ...          ...            ...                 ...                 ...
# 16601  478704134         Milosz            Brooklyn  Bedford-Stuyvesant
# 16602  419863661        Yessica              Queens              Corona
# 16603  471441645           Dyar               Bronx            Allerton
# 16604   16978120           Chip           Manhattan              Harlem
# 16605  206952308          Daria           Manhattan             Midtown
#
#         latitude  longitude        room_type  price  ...  last_review  \
# 0      40.702620 -73.898000  Entire home/apt  471.0  ...   2022-11-03
# 1      40.720270 -73.955130  Entire home/apt  225.0  ...   2023-09-13
# 2      40.686700 -73.948560     Private room   80.0  ...   2023-11-17
# 3      40.732210 -73.986890  Entire home/apt   83.0  ...   2023-08-11
# 4      40.668600 -73.987230  Entire home/apt   90.0  ...   2022-05-31
# ...          ...        ...              ...    ...  ...          ...
# 16601  40.686001 -73.943693  Entire home/apt  135.0  ...   2023-01-10
# 16602  40.745100 -73.864880     Private room   68.0  ...   2023-10-16
# 16603  40.867770 -73.860180  Entire home/apt  100.0  ...   2023-10-07
# 16604  40.830791 -73.949509     Private room   50.0  ...   2023-12-10
# 16605  40.762250 -73.978280  Entire home/apt  130.0  ...   2023-06-01
#
#        reviews_per_month calculated_host_listings_count  availability_365  \
# 0                   0.07                              9               365
# 1                   0.49                              5                90
# 2                   1.00                              2               363
# 3                   0.12                             30               106
# 4                   2.90                              3               188
# ...                  ...                            ...               ...
# 16601               0.97                              1               262
# 16602               2.68                              2               180
# 16603               2.21                              5               365
# 16604               0.21                              4                42
# 16605               0.20                              5               365
#
#        number_of_reviews_ltm  license  rating  bedrooms  beds  baths
# 0                          0        0     NaN         5     8      2
# 1                          7        0    4.60         2     2      1
# 2                         12        0    4.93         1     1      1
# 3                          1        0     NaN         1     1      1
# 4                          0        0    4.93         1     1      1
# ...                      ...      ...     ...       ...   ...    ...
# 16601                      1        0    4.87         3     3      1
# 16602                     16        0    4.69         1     1      1
# 16603                     24        0    4.73         1     1      1
# 16604                      1        0    4.84         1     1      1
# 16605                      2        0     NaN         1     1      1
#
# [16606 rows x 22 columns]

# %% [markdown]
# ### usuwamy kolumny

# %%
data = data.drop(["id", "name", "host_id", "host_name", "neighbourhood", "neighbourhood_group", "number_of_reviews_ltm", "bedrooms"], axis = 1)
data
# Out:
#         latitude  longitude        room_type  price  minimum_nights  \
# 0      40.702620 -73.898000  Entire home/apt  471.0              30
# 1      40.720270 -73.955130  Entire home/apt  225.0              30
# 2      40.686700 -73.948560     Private room   80.0              30
# 3      40.732210 -73.986890  Entire home/apt   83.0              30
# 4      40.668600 -73.987230  Entire home/apt   90.0              30
# ...          ...        ...              ...    ...             ...
# 16601  40.686001 -73.943693  Entire home/apt  135.0              30
# 16602  40.745100 -73.864880     Private room   68.0              30
# 16603  40.867770 -73.860180  Entire home/apt  100.0              30
# 16604  40.830791 -73.949509     Private room   50.0              30
# 16605  40.762250 -73.978280  Entire home/apt  130.0              30
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      1  2022-11-03               0.07
# 1                     52  2023-09-13               0.49
# 2                    101  2023-11-17               1.00
# 3                      2  2023-08-11               0.12
# 4                    479  2022-05-31               2.90
# ...                  ...         ...                ...
# 16601                 15  2023-01-10               0.97
# 16602                 16  2023-10-16               2.68
# 16603                 30  2023-10-07               2.21
# 16604                 19  2023-12-10               0.21
# 16605                  2  2023-06-01               0.20
#
#        calculated_host_listings_count  availability_365  license  rating  \
# 0                                   9               365        0     NaN
# 1                                   5                90        0    4.60
# 2                                   2               363        0    4.93
# 3                                  30               106        0     NaN
# 4                                   3               188        0    4.93
# ...                               ...               ...      ...     ...
# 16601                               1               262        0    4.87
# 16602                               2               180        0    4.69
# 16603                               5               365        0    4.73
# 16604                               4                42        0    4.84
# 16605                               5               365        0     NaN
#
#        beds  baths
# 0         8      2
# 1         2      1
# 2         1      1
# 3         1      1
# 4         1      1
# ...     ...    ...
# 16601     3      1
# 16602     1      1
# 16603     1      1
# 16604     1      1
# 16605     1      1
#
# [16606 rows x 14 columns]

# %% [markdown]
# ### ordinal encoding dla 'room_type'

# %%
room_type_map = {
    'Entire home/apt' : 3,
    "Hotel room": 2,
    "Private room": 1,
    "Shared room": 0
}
data["room_type"] = data["room_type"].map(room_type_map)
data
# Out:
#         latitude  longitude  room_type  price  minimum_nights  \
# 0      40.702620 -73.898000          3  471.0              30
# 1      40.720270 -73.955130          3  225.0              30
# 2      40.686700 -73.948560          1   80.0              30
# 3      40.732210 -73.986890          3   83.0              30
# 4      40.668600 -73.987230          3   90.0              30
# ...          ...        ...        ...    ...             ...
# 16601  40.686001 -73.943693          3  135.0              30
# 16602  40.745100 -73.864880          1   68.0              30
# 16603  40.867770 -73.860180          3  100.0              30
# 16604  40.830791 -73.949509          1   50.0              30
# 16605  40.762250 -73.978280          3  130.0              30
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                      1  2022-11-03               0.07
# 1                     52  2023-09-13               0.49
# 2                    101  2023-11-17               1.00
# 3                      2  2023-08-11               0.12
# 4                    479  2022-05-31               2.90
# ...                  ...         ...                ...
# 16601                 15  2023-01-10               0.97
# 16602                 16  2023-10-16               2.68
# 16603                 30  2023-10-07               2.21
# 16604                 19  2023-12-10               0.21
# 16605                  2  2023-06-01               0.20
#
#        calculated_host_listings_count  availability_365  license  rating  \
# 0                                   9               365        0     NaN
# 1                                   5                90        0    4.60
# 2                                   2               363        0    4.93
# 3                                  30               106        0     NaN
# 4                                   3               188        0    4.93
# ...                               ...               ...      ...     ...
# 16601                               1               262        0    4.87
# 16602                               2               180        0    4.69
# 16603                               5               365        0    4.73
# 16604                               4                42        0    4.84
# 16605                               5               365        0     NaN
#
#        beds  baths
# 0         8      2
# 1         2      1
# 2         1      1
# 3         1      1
# 4         1      1
# ...     ...    ...
# 16601     3      1
# 16602     1      1
# 16603     1      1
# 16604     1      1
# 16605     1      1
#
# [16606 rows x 14 columns]

# %% [markdown]
# ### Kodowanie daty 'last_review'

# %%
new_review = data["last_review"].apply(lambda x: x.timestamp())
a = new_review.min()
b = new_review.max()
new_review = new_review.apply(lambda x: (x - a) / (b - a))
data["last_review"] = new_review
data
# Out:
#         latitude  longitude  room_type  price  minimum_nights  \
# 0      40.702620 -73.898000          3  471.0              30
# 1      40.720270 -73.955130          3  225.0              30
# 2      40.686700 -73.948560          1   80.0              30
# 3      40.732210 -73.986890          3   83.0              30
# 4      40.668600 -73.987230          3   90.0              30
# ...          ...        ...        ...    ...             ...
# 16601  40.686001 -73.943693          3  135.0              30
# 16602  40.745100 -73.864880          1   68.0              30
# 16603  40.867770 -73.860180          3  100.0              30
# 16604  40.830791 -73.949509          1   50.0              30
# 16605  40.762250 -73.978280          3  130.0              30
#
#        number_of_reviews  last_review  reviews_per_month  \
# 0                      1     0.898937               0.07
# 1                     52     0.973081               0.49
# 2                    101     0.988430               1.00
# 3                      2     0.965289               0.12
# 4                    479     0.862102               2.90
# ...                  ...          ...                ...
# 16601                 15     0.914994               0.97
# 16602                 16     0.980874               2.68
# 16603                 30     0.978749               2.21
# 16604                 19     0.993861               0.21
# 16605                  2     0.948524               0.20
#
#        calculated_host_listings_count  availability_365  license  rating  \
# 0                                   9               365        0     NaN
# 1                                   5                90        0    4.60
# 2                                   2               363        0    4.93
# 3                                  30               106        0     NaN
# 4                                   3               188        0    4.93
# ...                               ...               ...      ...     ...
# 16601                               1               262        0    4.87
# 16602                               2               180        0    4.69
# 16603                               5               365        0    4.73
# 16604                               4                42        0    4.84
# 16605                               5               365        0     NaN
#
#        beds  baths
# 0         8      2
# 1         2      1
# 2         1      1
# 3         1      1
# 4         1      1
# ...     ...    ...
# 16601     3      1
# 16602     1      1
# 16603     1      1
# 16604     1      1
# 16605     1      1
#
# [16606 rows x 14 columns]

# %% [markdown]
# ### inputacja nanow w ratingu

# %%
from sklearn.linear_model import LinearRegression
df_to_pred = data.copy()
# Te dane będziemy musieli uzupełnic
to_fill = df_to_pred[df_to_pred['rating'].isna()]
# Na tych danych wyszkolimy nasz LinearRegression model
filled = data[df_to_pred.index.map(lambda x: x not in to_fill.index.to_numpy()).to_numpy()]
#
to_fill = to_fill.reset_index(drop = True)
filled = filled.reset_index(drop = True)
# Szkolimy model regresji liniowej
X = filled.drop("rating", axis = 1)
y = filled["rating"]
lr = LinearRegression()
lr.fit(X, y)
new_rating = lr.predict(to_fill.drop("rating", axis = 1))
pd.Series(new_rating)
# Wypełniamy nany
to_fill["rating"] = new_rating

# %%
#sprawdzamy
to_fill['rating'].isna().sum()
# Out:
# 0

# %%
# Pozostaje zatem przepisac ramke jako nowa df
df = pd.concat([to_fill, filled], axis = 0).reset_index(drop = True)
df
# Out:
#         latitude  longitude  room_type  price  minimum_nights  \
# 0      40.702620 -73.898000          3  471.0              30
# 1      40.732210 -73.986890          3   83.0              30
# 2      40.684210 -73.907890          1  150.0              30
# 3      40.874690 -73.901690          1  200.0              30
# 4      40.671320 -73.960900          1   32.0              30
# ...          ...        ...        ...    ...             ...
# 16601  40.745330 -73.919580          1   55.0              30
# 16602  40.686001 -73.943693          3  135.0              30
# 16603  40.745100 -73.864880          1   68.0              30
# 16604  40.867770 -73.860180          3  100.0              30
# 16605  40.830791 -73.949509          1   50.0              30
#
#        number_of_reviews  last_review  reviews_per_month  \
# 0                      1     0.898937               0.07
# 1                      2     0.965289               0.12
# 2                      1     0.594097               0.02
# 3                      1     0.481700               0.01
# 4                      1     0.783707               0.03
# ...                  ...          ...                ...
# 16601                  3     0.983943               0.21
# 16602                 15     0.914994               0.97
# 16603                 16     0.980874               2.68
# 16604                 30     0.978749               2.21
# 16605                 19     0.993861               0.21
#
#        calculated_host_listings_count  availability_365  license    rating  \
# 0                                   9               365        0  4.678690
# 1                                  30               106        0  4.742355
# 2                                   1                 0        0  4.670132
# 3                                   2                 0        0  4.593371
# 4                                   1               322        0  4.679929
# ...                               ...               ...      ...       ...
# 16601                               1               364        0  5.000000
# 16602                               1               262        0  4.870000
# 16603                               2               180        0  4.690000
# 16604                               5               365        0  4.730000
# 16605                               4                42        0  4.840000
#
#        beds  baths
# 0         8      2
# 1         1      1
# 2         1      1
# 3         1      1
# 4         1      1
# ...     ...    ...
# 16601     1      1
# 16602     3      1
# 16603     1      1
# 16604     1      1
# 16605     1      1
#
# [16606 rows x 14 columns]

# %% [markdown]
# ## transforamcje danych
# Ostatecznie:
# - uzywamy PYOD do usuniecia outlierow
# - uzywami yeo-johnson (oprocz latitude, longitude, room_type, license) i pozniej min_max_scaler

# %% [markdown]
# ### Usuwanie outlierów

# %%
# oprocz latitude, longtitude, room_type (kategoryczna), license (binarna)
cols = df.columns.to_numpy()
cols_to_pyod = [cols for cols in df.columns if cols not in ["latitude", "longitude", "room_type", "license"]]

from pyod.models.knn import KNN
clf = KNN(contamination=0.04)
clf.fit(df[cols_to_pyod])
df['outliers'] = clf.labels_
df['outliers'].value_counts()
# Out:
# 0    15941
# 1      665
# Name: outliers, dtype: int64

# %%
# usuwamy outliery
df = df[df['outliers'] == 0]
df = df.drop('outliers', axis = 1)
df
# Out:
#         latitude  longitude  room_type  price  minimum_nights  \
# 0      40.702620 -73.898000          3  471.0              30
# 1      40.732210 -73.986890          3   83.0              30
# 2      40.684210 -73.907890          1  150.0              30
# 3      40.874690 -73.901690          1  200.0              30
# 4      40.671320 -73.960900          1   32.0              30
# ...          ...        ...        ...    ...             ...
# 16601  40.745330 -73.919580          1   55.0              30
# 16602  40.686001 -73.943693          3  135.0              30
# 16603  40.745100 -73.864880          1   68.0              30
# 16604  40.867770 -73.860180          3  100.0              30
# 16605  40.830791 -73.949509          1   50.0              30
#
#        number_of_reviews  last_review  reviews_per_month  \
# 0                      1     0.898937               0.07
# 1                      2     0.965289               0.12
# 2                      1     0.594097               0.02
# 3                      1     0.481700               0.01
# 4                      1     0.783707               0.03
# ...                  ...          ...                ...
# 16601                  3     0.983943               0.21
# 16602                 15     0.914994               0.97
# 16603                 16     0.980874               2.68
# 16604                 30     0.978749               2.21
# 16605                 19     0.993861               0.21
#
#        calculated_host_listings_count  availability_365  license    rating  \
# 0                                   9               365        0  4.678690
# 1                                  30               106        0  4.742355
# 2                                   1                 0        0  4.670132
# 3                                   2                 0        0  4.593371
# 4                                   1               322        0  4.679929
# ...                               ...               ...      ...       ...
# 16601                               1               364        0  5.000000
# 16602                               1               262        0  4.870000
# 16603                               2               180        0  4.690000
# 16604                               5               365        0  4.730000
# 16605                               4                42        0  4.840000
#
#        beds  baths
# 0         8      2
# 1         1      1
# 2         1      1
# 3         1      1
# 4         1      1
# ...     ...    ...
# 16601     1      1
# 16602     3      1
# 16603     1      1
# 16604     1      1
# 16605     1      1
#
# [15941 rows x 14 columns]

# %% [markdown]
# ### yeo-johnson
# bez latitude, longitude, room_type, license

# %%
cols_to_johnson = [cols for cols in df.columns if cols not in ["latitude", "longitude", "room_type", "license"]]

from scipy.stats import yeojohnson
# korzystanie z yeo_johhsona
df_yeo = df.copy()
for col in cols_to_johnson:
    df_yeo[col], _ = yeojohnson(df[col])
df_yeo
# Out:
#         latitude  longitude  room_type     price  minimum_nights  \
# 0      40.702620 -73.898000          3  4.349582        9.727349
# 1      40.732210 -73.986890          3  3.434738        9.727349
# 2      40.684210 -73.907890          1  3.767077        9.727349
# 3      40.874690 -73.901690          1  3.920853        9.727349
# 4      40.671320 -73.960900          1  2.854393        9.727349
# ...          ...        ...        ...       ...             ...
# 16601  40.745330 -73.919580          1  3.190872        9.727349
# 16602  40.686001 -73.943693          3  3.709493        9.727349
# 16603  40.745100 -73.864880          1  3.317912        9.727349
# 16604  40.867770 -73.860180          3  3.541717        9.727349
# 16605  40.830791 -73.949509          1  3.132913        9.727349
#
#        number_of_reviews    last_review  reviews_per_month  \
# 0               0.677335   89664.001778           0.065720
# 1               1.059243  195176.867350           0.107960
# 2               0.677335    1703.995585           0.019634
# 3               0.677335     325.278308           0.009908
# 4               0.677335   21721.543367           0.029185
# ...                  ...            ...                ...
# 16601           1.324002  241739.274834           0.175758
# 16602           2.530828  108501.606905           0.513213
# 16603           2.581095  233408.667897           0.782119
# 16604           3.068367  227802.842625           0.735039
# 16605           2.714846  270640.029098           0.175758
#
#        calculated_host_listings_count  availability_365  license  \
# 0                            1.038272         55.411327        0
# 1                            1.151104         25.683723        0
# 2                            0.529391          0.000000        0
# 3                            0.725473          0.000000        0
# 4                            0.529391         51.299645        0
# ...                               ...               ...      ...
# 16601                        0.529391         55.317988        0
# 16602                        0.529391         45.172866        0
# 16603                        0.725473         35.790666        0
# 16604                        0.941464         55.411327        0
# 16605                        0.895907         14.185657        0
#
#              rating      beds     baths
# 0      2.761741e+08  0.382909  0.628101
# 1      3.180145e+08  0.320938  0.480012
# 2      2.709542e+08  0.320938  0.480012
# 3      2.280323e+08  0.320938  0.480012
# 4      2.769376e+08  0.320938  0.480012
# ...             ...       ...       ...
# 16601  5.541466e+08  0.320938  0.480012
# 16602  4.200069e+08  0.373762  0.480012
# 16603  2.832151e+08  0.320938  0.480012
# 16604  3.094645e+08  0.320938  0.480012
# 16605  3.936414e+08  0.320938  0.480012
#
# [15941 rows x 14 columns]

# %%
# ZAPISUJE DLA POZNIEJSZEGO UZYCIA W MAPKACH
lat_max = df_yeo['latitude'].max()
lat_min = df_yeo['latitude'].min()
long_max = df_yeo['longitude'].max()
long_min = df_yeo['longitude'].min()

# %% [markdown]
# ### min_max_scaler

# %%
from sklearn.preprocessing import MinMaxScaler

# WSZYSTKIE kolumny
df_final = df_yeo.copy()
scaler = MinMaxScaler()
df_final[df_final.columns] = scaler.fit_transform(df_final[df_final.columns])
df_final
# Out:
#        latitude  longitude  room_type     price  minimum_nights  \
# 0      0.492428   0.656185   1.000000  0.758784        0.126667
# 1      0.564453   0.490405   1.000000  0.452508        0.126667
# 2      0.447617   0.637740   0.333333  0.563770        0.126667
# 3      0.911261   0.649303   0.333333  0.615252        0.126667
# 4      0.416242   0.538876   0.333333  0.258218        0.126667
# ...         ...        ...        ...       ...             ...
# 16601  0.596388   0.615938   0.333333  0.370865        0.126667
# 16602  0.451976   0.570967   1.000000  0.544492        0.126667
# 16603  0.595828   0.717954   0.333333  0.413396        0.126667
# 16604  0.894417   0.726720   1.000000  0.488323        0.126667
# 16605  0.804408   0.560121   0.333333  0.351462        0.126667
#
#        number_of_reviews  last_review  reviews_per_month  \
# 0               0.000000     0.309020           0.051765
# 1               0.086282     0.672663           0.090941
# 2               0.000000     0.005873           0.009021
# 3               0.000000     0.001121           0.000000
# 4               0.000000     0.074862           0.017879
# ...                  ...          ...                ...
# 16601           0.146097     0.833137           0.153823
# 16602           0.418746     0.373943           0.466805
# 16603           0.430102     0.804426           0.716210
# 16604           0.540188     0.785106           0.672544
# 16605           0.460320     0.932741           0.153823
#
#        calculated_host_listings_count  availability_365  license    rating  \
# 0                            0.737167          1.000000      0.0  0.498299
# 1                            0.900616          0.463510      0.0  0.573815
# 2                            0.000000          0.000000      0.0  0.488878
# 3                            0.284046          0.000000      0.0  0.411410
# 4                            0.000000          0.925797      0.0  0.499677
# ...                               ...               ...      ...       ...
# 16601                        0.000000          0.998316      0.0  1.000000
# 16602                        0.000000          0.815228      0.0  0.757897
# 16603                        0.284046          0.645909      0.0  0.511007
# 16604                        0.596931          1.000000      0.0  0.558384
# 16605                        0.530937          0.256006      0.0  0.710311
#
#            beds     baths
# 0      0.985259  0.757568
# 1      0.000000  0.578954
# 2      0.000000  0.578954
# 3      0.000000  0.578954
# 4      0.000000  0.578954
# ...         ...       ...
# 16601  0.000000  0.578954
# 16602  0.839836  0.578954
# 16603  0.000000  0.578954
# 16604  0.000000  0.578954
# 16605  0.000000  0.578954
#
# [15941 rows x 14 columns]

# %% [markdown]
# ostateczna nazwa danych po wszytski transformacjach to df_final

# %% [markdown]
# # Modele

# %% [markdown]
# ## 1. K-means

# %%
from sklearn.cluster import KMeans

# %%
seed = 17

# %%
def count_clustering_scores(X, cluster_num, model, score_fun):
    if isinstance(cluster_num, int):
        cluster_num_iter = [cluster_num]
    else:
        cluster_num_iter = cluster_num
        
    scores = []    
    for k in cluster_num_iter:
        model_instance = model(n_clusters=k, random_state = seed)
        labels = model_instance.fit_predict(X)
        wcss = score_fun(X, labels)
        scores.append(wcss)
    
    if isinstance(cluster_num, int):
        return scores[0]
    else:
        return scores

# %% [markdown]
# ### 1.1 Wskaznik Silhouette

# %%
from sklearn.metrics import silhouette_score

# %%
cluster_num_seq = range(2, 50)
silhouette_vec = count_clustering_scores(df_final, cluster_num_seq, KMeans, silhouette_score)
plt.plot(cluster_num_seq, silhouette_vec, 'x-', color = "brown")
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.grid()
plt.show()

# %% [markdown]
# Tu najlepiej sprawdza się 29 klastrów (jeśli chcemy mieć dużo klastrów co wydaje się sensowne w naszej rekomendajcji) lub 12 klastrów (Jesli brać pod uwagę sama metrykę, ale to może być za mało klastrów z perspektywy problemu)

# %% [markdown]
# ### 1.2 Calinski Harabash score

# %%
from sklearn.metrics import calinski_harabasz_score

# %%
cluster_num_seq = range(2, 51)
calinski_vec = count_clustering_scores(df_final, cluster_num_seq, KMeans, calinski_harabasz_score)
plt.plot(cluster_num_seq, calinski_vec, 'x-', color = "brown")
plt.xlabel('k')
plt.ylabel('Calinski_Harabasz score')
plt.grid()
plt.show()

# %% [markdown]
# Tutaj nie dostajemy zadowalającej metryki tam gdzie chcemy (2 klastry nie podlegają pod nasz problem rekomendacji)

# %% [markdown]
# ### 1.4 Davies Bouldin score

# %%
from sklearn.metrics import davies_bouldin_score

# %%
cluster_num_seq = range(2, 51)
davies_vec = count_clustering_scores(df_final, cluster_num_seq, KMeans, davies_bouldin_score)
plt.plot(cluster_num_seq, davies_vec, 'x-', color = "brown")
plt.xlabel('k')
plt.ylabel('Davies_Bouldin score')
plt.grid()
plt.show()

# %% [markdown]
# Tutaj najlepiej sprawdza się 19 klastrów co jest już sensowne w przypadku naszego problemu rekomendacji

# %% [markdown]
# ### 1.5 Czy wyniki są lepsze dla innego algorithmu kmeans?

# %%
scores = []    
for k in range(2, 51):
    model_instance = KMeans(n_clusters=k, random_state = seed, algorithm = "elkan")
    labels = model_instance.fit_predict(df_final)
    wcss = davies_bouldin_score(df_final, labels)
    scores.append(wcss)
plt.plot(cluster_num_seq, scores, 'x-', color = "brown")
plt.xlabel('k')
plt.ylabel('Davies_Bouldin score')
plt.grid()
plt.show()

# %% [markdown]
# Jak widać wyniki sa takie same (różnica między algorytmami jest tylko w szybkości wykonywania się)

# %% [markdown]
# ### 1.6 Wizualizacja

# %% [markdown]
# #### PCA

# %% [markdown]
# Ze wskaźników wyniknęło, że najlepsza liczba klastrów to: 12, 19, 29

# %%
from sklearn.decomposition import PCA

# %%
# Dla 12
pca = PCA()
kmeans = KMeans(n_clusters=12, random_state = seed)
result = pca.fit_transform(df_final)
labels = kmeans.fit_predict(df_final)
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = labels, palette=sns.color_palette("hls", 12))
plt.show()

# %%
# Dla 19
pca = PCA()
kmeans = KMeans(n_clusters=19, random_state = seed)
result = pca.fit_transform(df_final)
labels = kmeans.fit_predict(df_final)
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = labels, palette=sns.color_palette("hls", 12))
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21152\4294119652.py:6: UserWarning:
# The palette list has fewer values (12) than needed (19) and will cycle, which may produce an uninterpretable plot.
#   sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = labels, palette=sns.color_palette("hls", 12))

# %% [markdown]
# Dalsze wizualizacje nie beda miały sensu, jeśli robić to w ten sposób. Kolory się zapętlają. A jak to wygląda na mapce? Końcowo przecież o to nam chodzi

# %% [markdown]
# #### Mapka

# %%
df
# Out:
#         latitude  longitude  room_type  price  minimum_nights  \
# 0      40.702620 -73.898000          3  471.0              30
# 1      40.732210 -73.986890          3   83.0              30
# 2      40.684210 -73.907890          1  150.0              30
# 3      40.874690 -73.901690          1  200.0              30
# 4      40.671320 -73.960900          1   32.0              30
# ...          ...        ...        ...    ...             ...
# 16601  40.745330 -73.919580          1   55.0              30
# 16602  40.686001 -73.943693          3  135.0              30
# 16603  40.745100 -73.864880          1   68.0              30
# 16604  40.867770 -73.860180          3  100.0              30
# 16605  40.830791 -73.949509          1   50.0              30
#
#        number_of_reviews  last_review  reviews_per_month  \
# 0                      1     0.898937               0.07
# 1                      2     0.965289               0.12
# 2                      1     0.594097               0.02
# 3                      1     0.481700               0.01
# 4                      1     0.783707               0.03
# ...                  ...          ...                ...
# 16601                  3     0.983943               0.21
# 16602                 15     0.914994               0.97
# 16603                 16     0.980874               2.68
# 16604                 30     0.978749               2.21
# 16605                 19     0.993861               0.21
#
#        calculated_host_listings_count  availability_365  license    rating  \
# 0                                   9               365        0  4.678690
# 1                                  30               106        0  4.742355
# 2                                   1                 0        0  4.670132
# 3                                   2                 0        0  4.593371
# 4                                   1               322        0  4.679929
# ...                               ...               ...      ...       ...
# 16601                               1               364        0  5.000000
# 16602                               1               262        0  4.870000
# 16603                               2               180        0  4.690000
# 16604                               5               365        0  4.730000
# 16605                               4                42        0  4.840000
#
#        beds  baths
# 0         8      2
# 1         1      1
# 2         1      1
# 3         1      1
# 4         1      1
# ...     ...    ...
# 16601     1      1
# 16602     3      1
# 16603     1      1
# 16604     1      1
# 16605     1      1
#
# [15941 rows x 14 columns]

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe'

# %%
# Dla 12 klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=12, random_state = seed)
labels = kmeans.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# poprzez dwukrotne nacisniecie na kropke (szybkie) w labels mozemy zaznaczyc, zeby pokazywalo tylko jeden klaster
# Po krotkiej analizie stwierdzic mozna, ze to za malo klastrow
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_30.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Dla 19 klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=19, random_state = seed)
labels = kmeans.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Juz lepiej (np klaster 7), ale dalej te mieszkania sa rozrzucone po calym manhatanie
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_31.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Dla 29 klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=29, random_state = seed)
labels = kmeans.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_32.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# #### Konkluzja

# %% [markdown]
# W naszej ramce wsm dalej mamy wiele w gruncie nie istotnych kolumn. Nie wiem czy da się ustawiać wagi do kolumn (żeby taki kmeans bral pod uwage bardziej longitude, latitude, rating i price pod uwage niz inne kolumny). Ale zawsze mozna przeciez zostawic najistotniejsze kolumny i sprawdzic co sie stanie. (No raczej powinno sie poprawic przynajmniej "na oko" (patrzac na mapke))

# %%
df.columns
# Out:
# Index(['latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365', 'license',
#        'rating', 'beds', 'baths', 'labels'],
#       dtype='object')

# %% [markdown]
# #### Zostawiajac najistotniejsze kolumny...

# %%
# Dla 12 klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=12, random_state = seed)
# Przewiduje klastry na tylko istotnych kolumnach
labels = kmeans.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Dalej za mało klastrów
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_34.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Dla 19 klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=19, random_state = seed)
# Przewiduje klastry na tylko istotnych kolumnach
labels = kmeans.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_35.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Dla 29 klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=29, random_state = seed)
# Przewiduje klastry na tylko istotnych kolumnach
labels = kmeans.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# No ładniej sie robi (np wyłapało klaster 7)
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_36.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
# Dla 78? klastrów
# przewiduje kmeans i labele ustawiam
kmeans = KMeans(n_clusters=78, random_state = seed)
# Przewiduje klastry na tylko istotnych kolumnach
labels = kmeans.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# No nie wiem mi się tak podoba
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_37.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Jeszcze z ciekawości zobaczmy jak zachowują się metryki jeżeli zostawimy tylko naistiotniejsze kolumny

# %%
scores = []    
for k in range(2, 101):
    model_instance = KMeans(n_clusters=k, random_state = seed)
    labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
    wcss = davies_bouldin_score(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1), labels)
    scores.append(wcss)
plt.plot(range(2, 101), scores, 'x-', color = "brown")
plt.xlabel('k')
plt.ylabel('Davies_Bouldin score')
plt.grid()
plt.show()
# Rzeczywisie widac, ze jezeli chcemy duza liczbe klastrow to okolo 90 wydaje sie nie najgorszym pomyslem

# %%
scores = []    
for k in range(2, 101):
    model_instance = KMeans(n_clusters=k, random_state = seed)
    labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
    wcss = silhouette_score(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1), labels)
    scores.append(wcss)
plt.plot(range(2, 101), scores, 'x-', color = "brown")
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.grid()
plt.show()
# Ale nie jest juz tak wg tej metryki

# %% [markdown]
# ## 2. DBSCAN (Density-Based Spatial Clustering of Applications with Noise)

# %%
from sklearn.cluster import DBSCAN

# %% [markdown]
# ### 2.1 strojenie parametrów

# %% [markdown]
# #### eps
# odnosi się do maksymalnej odległości między dwoma punktami, które mogą być uznane za sąsiadów; wplywa na to ile punktow jest unzawanych za czesc klastra
#
# Uzyjemy metody k-nearest neighbors (KNN)

# %%
from sklearn.neighbors import NearestNeighbors
neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(df_final)
distances, indices = nbrs.kneighbors(df_final)

distances = np.sort(distances, axis=0)
distances = distances[:,1]

plt.plot(distances)
plt.title("Wykres odległości k-najbliższych sąsiadów")
plt.xlabel("Indeksy punktów")
plt.ylabel("Odległość")
plt.show()

# %% [markdown]
# Szukamy punktu gdzie nastepuje nagly skok w odleglosciach (szybko rosnie do gory).
#
# U na będzie to około między 0.3 a 0.4

# %% [markdown]
# #### min_samples
# Określa minimalną liczbę punktów w sąsiedztwie punktu centralnego (core point).
#
# Zazwyczaj jego wartość ustawia sie na wartosc wieksza niz wymiarowosc zbioru danych.
# Zatem, skoro nasz dane są 14-wymiarowe to min_samples powinno wynosic co najmniej 15.

# %% [markdown]
# #### strojenie

# %%
# UWAGA DLUGO SIE WYKONUJE - ok.18min
from sklearn.metrics import silhouette_score
# eps_values to 0.3, 0.35,0.4
eps_values = [0.3, 0.35, 0.4]
min_samples_values = np.arange(15, 25, 1)
best_score = -1
best_eps = 0
best_min_samples = 0

for eps in eps_values:
    for min_sample in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_sample)
        labels = dbscan.fit_predict(df_final)
        # ignorowanie wynikow z jednym klastrem
        if len(np.unique(labels)) > 1:
            score = silhouette_score(df_final, labels)
            if score > best_score:
                best_score = score
                best_eps = eps
                best_min_samples = min_sample

print(f"Best score: {best_score}, eps: {best_eps}, min_samples: {best_min_samples}")
# Out:
# Best score: 0.0570646390603561, eps: 0.4, min_samples: 20

# %%
# UWAGA DLUGO SIE WYKONUJE - ok.18min
from sklearn.metrics import silhouette_score
# eps_values to 0.3-1 co 0.05
eps_values = np.arange(0.3, 1, 0.05)
min_samples_values = np.arange(15, 25, 1)
best_score = -1
best_eps = 0
best_min_samples = 0

for eps in eps_values:
    for min_sample in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_sample)
        labels = dbscan.fit_predict(df_final)
       # ignorowanie wynikow z jednym klastrem
        if len(np.unique(labels)) > 1:
            score = silhouette_score(df_final, labels)
            if score > best_score:
                best_score = score
                best_eps = eps
                best_min_samples = min_sample

print(f"Best score: {best_score}, eps: {best_eps}, min_samples: {best_min_samples}")
# Out:
# Best score: 0.2335570384327045, eps: 0.8999999999999999, min_samples: 15

# %% [markdown]
# Co ciekawe gdy patrzymy na przedziale eps 0.3-0.4 (czyli takim jaki powinien byc wedlug wyznaczania eps metoda KNN) to najlpeszy wynik (wg silhouette score) jest dla eps=0.4 min_samples=20 - wynik: 0.057064
#
# jednak dla wiekszych przedziałow (gdy patrzymy juz do 1), najlepszy wynik wychodzi dla eps=0.8, min_samples=15 - wynik: 0.23355704
#
# Dlatego sprawdzimy oba te wyniki

# %% [markdown]
# ### 2.2 model

# %%
# dla eps=0.4
dbscan_eps_4 = DBSCAN(eps=0.4, min_samples=20)
clusters_dbscan_4 = dbscan_eps_4.fit_predict(df_final)

# dla eps=.8
dbscan_eps_8 = DBSCAN(eps=0.8, min_samples=15)
clusters_dbscan_8 = dbscan_eps_8.fit_predict(df_final)

# %% [markdown]
# ### 2.3 wyniki

# %% [markdown]
# #### wskaznik Silhouette

# %%
from sklearn.metrics import silhouette_score

score_4 = silhouette_score(df_final, clusters_dbscan_4)
score_8 = silhouette_score(df_final, clusters_dbscan_8)

print(f"Silhouette score dla eps=0.4 i min_smaples=8: {score_4}")
print(f"Silhouette score dla eps=0.8 i min_smaples=3: {score_8}")
# Out:
# Silhouette score dla eps=0.4 i min_smaples=8: 0.0570646390603561
# Silhouette score dla eps=0.8 i min_smaples=3: 0.193179172139691

# %% [markdown]
# ewidentnie widizmy tu ze dla eps=0.8, min_samples=3 wynik jest lepszy

# %% [markdown]
# #### wizualizacja

# %%
from sklearn.decomposition import PCA
pca = PCA()
result = pca.fit_transform(df_final)

# %% [markdown]
# Dla eps=0.4 i min_samples=20

# %%
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = clusters_dbscan_4[:], palette=sns.color_palette("hls", 8))
plt.show()

# %% [markdown]
# Dla eps=0.8 i min_samples=15

# %%
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = clusters_dbscan_8[:], palette=sns.color_palette("hls", 3))
plt.show()

# %% [markdown]
# #### indeks Daviesa-Bouldina
# Niskie wartości tego indeksu sugerują lepsze klastrowanie, co oznacza, że klastry są dobrze oddzielone i mają niską wariancję wewnętrzną.

# %%
from sklearn.metrics import davies_bouldin_score

davies_bouldin_score_4 = davies_bouldin_score(df_final, clusters_dbscan_4)
davies_bouldin_score_8 = davies_bouldin_score(df_final, clusters_dbscan_8)

print(f"Indeks Daviesa-Bouldina dla eps=0.4 i min_smaples=20: {davies_bouldin_score_4}")
print(f"Indeks Daviesa-Bouldina dla eps=0.8 i min_smaples=15: {davies_bouldin_score_8}")
# Out:
# Indeks Daviesa-Bouldina dla eps=0.4 i min_smaples=8: 2.008856764154024
# Indeks Daviesa-Bouldina dla eps=0.8 i min_smaples=3: 1.9062054177808954

# %% [markdown]
# Wynik dla eps=0.8, min_samples=3 jest lepszy -> czyli tak samo jak w shilouette score

# %% [markdown]
# Ostatecznie jednak jedynym sensownym wynikiem jest ten dla eps=0.4, min_samples=20, ponieważ ten drugi tworzy tylko 3 klastry co w naszym przypadku nie ma sensu

# %% [markdown]
# #### Mapki

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'iframe'

# %% [markdown]
# ##### Wszystkie kolumny

# %%
# przewiduje kmeans i labele ustawiam
model_instance = DBSCAN(eps=0.4, min_samples=20)
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_62.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Istotne kolumny

# %%
# przewiduje kmeans i labele ustawiam
model_instance = DBSCAN(eps=0.1, min_samples=20)
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_63.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## 3. Klasteryzacja hierarchiczna

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster import hierarchy
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ### 3.1 Davies_Bouldin score

# %%
# porównajmy wyniki z tymi z kmeans

# %%
linkages = ['ward', 'complete', 'average', 'single']

# %%
# UWAGA NIE WYKONYWAC TEJ KOMORKI (robi się bardzo długo) (ponad godzina)
cluster_num_seq = range(20, 100)
davies_vec_kmeans = count_clustering_scores(df_final, cluster_num_seq, KMeans, davies_bouldin_score)
davies_vec_hierarchical = {'ward': [], 'complete': [], 'average': [], 'single': []}
for linkage in linkages:
    for k in cluster_num_seq:
        model_instance = AgglomerativeClustering(n_clusters=k, linkage=linkage)
        labels = model_instance.fit_predict(df_final)
        wcss = davies_bouldin_score(df_final, labels)
        davies_vec_hierarchical[linkage].append(wcss)

ax = plt.figure().gca()
plt.plot(cluster_num_seq, davies_vec_kmeans, 'x-', color = "brown", label="KMeans")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.plot(cluster_num_seq, davies_vec_hierarchical['ward'], 'x-', color = "blue", label="Hierarchical ward")
plt.plot(cluster_num_seq, davies_vec_hierarchical['complete'], 'x-', color = "red", label="Hierarchical complete")
plt.plot(cluster_num_seq, davies_vec_hierarchical['single'], 'x-', color = "green", label="Hierarchical single")
plt.plot(cluster_num_seq, davies_vec_hierarchical['average'], 'x-', color = "black", label="Hierarchical average")
plt.xlabel('k')
plt.ylabel('Davies_Bouldin score')
plt.legend(loc="lower left")
plt.grid()
plt.savefig("output.jpg")
plt.show()

# %% [markdown]
# Jak widać single linkage deklasuje resztę w tej metryce. Pytanie czy to oznacza, że ogólnie jest lepszy.
# Dla silhouette_score nawet nie będę patrzył, chyba, że na noc zostawię komputer

# %%
# silhouette_score (Zostawic na noc)
cluster_num_seq = range(20, 100)
silhouette_vec_kmeans = count_clustering_scores(df_final, cluster_num_seq, KMeans, silhouette_score)
silhouette_vec_hierarchical = {'ward': [], 'complete': [], 'average': [], 'single': []}
for linkage in linkages:
    for k in cluster_num_seq:
        model_instance = AgglomerativeClustering(n_clusters=k, linkage=linkage)
        labels = model_instance.fit_predict(df_final)
        wcss = silhouette_score(df_final, labels)
        silhouette_vec_hierarchical[linkage].append(wcss)

ax = plt.figure().gca()
plt.plot(cluster_num_seq, silhouette_vec_kmeans, 'x-', color = "brown", label="KMeans")
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.plot(cluster_num_seq, silhouette_vec_hierarchical['ward'], 'x-', color = "blue", label="Hierarchical ward")
plt.plot(cluster_num_seq, silhouette_vec_hierarchical['complete'], 'x-', color = "red", label="Hierarchical complete")
plt.plot(cluster_num_seq, silhouette_vec_hierarchical['single'], 'x-', color = "green", label="Hierarchical single")
plt.plot(cluster_num_seq, silhouette_vec_hierarchical['average'], 'x-', color = "black", label="Hierarchical average")
plt.xlabel('k')
plt.ylabel('Silhouette score')
plt.legend(loc="lower left")
plt.grid()
plt.savefig("output2.jpg")
plt.show()

# %% [markdown]
# Dobra to zobaczmy jak radzić sobie będą teraz różne linkage na mapkach

# %% [markdown]
# ### 3.2 Mapki

# %% [markdown]
# #### 3.2.1 30 klastrów

# %%
n_clusters = 30

# %% [markdown]
# ##### Single (wszystkie kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='single')
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Zbyt duże różnice w wielkości klastrów
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_69.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Single (istotne kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='single')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Również słabo, że niektóre klastry są bardzo małe
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_70.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Average (wszystkie kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='average')
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Zbyt duże różnice w wielkości klastrów (dalej)
# Out:
# C:\Users\domin\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_38.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Average (istotniejsze kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='average')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# C:\Users\domin\anaconda3\Lib\site-packages\plotly\express\_core.py:1979: FutureWarning:
#
# When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_39.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Complete (wszystkie kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='complete')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_150.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Complete (istotniejsze kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='complete')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_151.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Ward (wszystkie kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_96.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### Ward (istotniejsze kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_100.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# #### 3.2.2 90 klastrów

# %% [markdown]
# ##### WARD (istotniejsze kolumny)

# %%
# przewiduje kmeans i labele ustawiam
model_instance = AgglomerativeClustering(n_clusters=90, linkage='ward')
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_154.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ## 4. GMM (Gaussian Mixture Model)

# %%
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ### 4.1 strojenie parametrów - n_components(liczba klastrów)

# %% [markdown]
# #### AIC i BIC

# %%
n_components = np.arange(1, 35)
models = [GaussianMixture(n, covariance_type='full', random_state=42).fit(X) for n in n_components]

plt.plot(n_components, [m.bic(X) for m in models], label='BIC')
plt.plot(n_components, [m.aic(X) for m in models], label='AIC')
plt.legend(loc='best')
plt.xlabel('Liczba składników')
plt.ylabel('Wartość kryterium')
plt.title('BIC i AIC w zależności od liczby składników')
plt.show()

# %% [markdown]
# Zarówno BIC, jak i AIC mają podobne wartości. W obu przypadkach szukamy miejsca gdzie wartości są najmniejsze. W tym przypadku wybieramy jest pare takich miejsc - 3, 15, 17, 19. 27 takze wydaje sie okej.

# %% [markdown]
# Shilouette score

# %%
from sklearn.metrics import silhouette_score
# Zakres liczby składników do przetestowania
range_n_components = range(2, 40)

# Lista na wyniki wskaźnika Silhouette
silhouette_scores = []

for n_components in range_n_components:
    # Inicjalizacja modelu GMM
    gmm = GaussianMixture(n_components=n_components, random_state=42)
    # Dopasowanie modelu
    gmm.fit(df_final)
    # Przewidywanie klastrów
    labels = gmm.predict(df_final)
    # Obliczanie wskaźnika Silhouette
    silhouette_avg = silhouette_score(df_final, labels)
    silhouette_scores.append(silhouette_avg)
    print(f"Dla n_components = {n_components} średni wskaźnik Silhouette wynosi: {silhouette_avg}")

# Wykres wskaźnika Silhouette dla różnych liczby składników
plt.figure(figsize=(10, 6))
plt.plot(range_n_components, silhouette_scores, marker='o')
plt.xlabel('n_components')
plt.ylabel('Średni wskaźnik Silhouette')
plt.title('Wskaźnik Silhouette dla różnych liczby składników w GMM')
plt.show()
# Out:
# Dla n_components = 2 średni wskaźnik Silhouette wynosi: 0.1647379419941684
# Dla n_components = 3 średni wskaźnik Silhouette wynosi: 0.19417609750835213
# Dla n_components = 4 średni wskaźnik Silhouette wynosi: 0.16059463540423874
# Dla n_components = 5 średni wskaźnik Silhouette wynosi: 0.047792540319086266
# Dla n_components = 6 średni wskaźnik Silhouette wynosi: 0.038095377298791123
# Dla n_components = 7 średni wskaźnik Silhouette wynosi: 0.07920950487320558
# Dla n_components = 8 średni wskaźnik Silhouette wynosi: 0.09658420239768438
# Dla n_components = 9 średni wskaźnik Silhouette wynosi: 0.0759929197422435
# Dla n_components = 10 średni wskaźnik Silhouette wynosi: 0.08382440628346319
# Dla n_components = 11 średni wskaźnik Silhouette wynosi: 0.021602467732752477
# Dla n_components = 12 średni wskaźnik Silhouette wynosi: 0.08356296615649028
# Dla n_components = 13 średni wskaźnik Silhouette wynosi: 0.04010429035022918
# Dla n_components = 14 średni wskaźnik Silhouette wynosi: 0.018433410641530215
# Dla n_components = 15 średni wskaźnik Silhouette wynosi: 0.009611659876758744
# Dla n_components = 16 średni wskaźnik Silhouette wynosi: 0.01280811913318296
# Dla n_components = 17 średni wskaźnik Silhouette wynosi: 0.05476006278119834
# Dla n_components = 18 średni wskaźnik Silhouette wynosi: 0.04086874489995635
# Dla n_components = 19 średni wskaźnik Silhouette wynosi: 0.055511754879016946
# Dla n_components = 20 średni wskaźnik Silhouette wynosi: 0.01853272565797224
# Dla n_components = 21 średni wskaźnik Silhouette wynosi: 0.008768318261657549
# Dla n_components = 22 średni wskaźnik Silhouette wynosi: -0.004017235911270912
# Dla n_components = 23 średni wskaźnik Silhouette wynosi: -0.004912530786048188
# Dla n_components = 24 średni wskaźnik Silhouette wynosi: 0.018361525389437115
# Dla n_components = 25 średni wskaźnik Silhouette wynosi: 0.01075267520053883
# Dla n_components = 26 średni wskaźnik Silhouette wynosi: 0.028021207083830466
# Dla n_components = 27 średni wskaźnik Silhouette wynosi: 0.03168817353735847
# Dla n_components = 28 średni wskaźnik Silhouette wynosi: 0.016420902450144017
# Dla n_components = 29 średni wskaźnik Silhouette wynosi: 0.012026394083847067
# Dla n_components = 30 średni wskaźnik Silhouette wynosi: 0.007946195631971879
# Dla n_components = 31 średni wskaźnik Silhouette wynosi: 0.003932167844019289
# Dla n_components = 32 średni wskaźnik Silhouette wynosi: 0.020011940218574775
# Dla n_components = 33 średni wskaźnik Silhouette wynosi: 0.01793221824597375
# Dla n_components = 34 średni wskaźnik Silhouette wynosi: 0.008835035745236888
# Dla n_components = 35 średni wskaźnik Silhouette wynosi: 0.026133420199495393
# Dla n_components = 36 średni wskaźnik Silhouette wynosi: 0.008258128358130785
# Dla n_components = 37 średni wskaźnik Silhouette wynosi: -0.010565165033713188
# Dla n_components = 38 średni wskaźnik Silhouette wynosi: -0.009446955976123711
# Dla n_components = 39 średni wskaźnik Silhouette wynosi: 0.005089424795577368

# %% [markdown]
# Widzimy ze zdecydowanie najlepszy wynik jest dla 3 klastrow (to samo pokazaly BIC i AIC). Równiez 8, 10,11,17 i 19 mają dobre wyniki. Także 27 może być ciekawe.

# %% [markdown]
# David Bouldin score

# %%
from sklearn.metrics import davies_bouldin_score
# Zakres liczby składników do przetestowania
range_n_components = range(2, 40)

# Lista na wyniki indeksu Daviesa-Bouldina
davies_bouldin_scores = []

for n_components in range_n_components:
    # Inicjalizacja modelu GMM
    gmm = GaussianMixture(n_components=n_components, random_state=42)
    # Dopasowanie modelu
    gmm.fit(df_final)
    # Przewidywanie klastrów
    labels = gmm.predict(df_final)
    # Obliczanie indeksu Daviesa-Bouldina
    db_score = davies_bouldin_score(df_final, labels)
    davies_bouldin_scores.append(db_score)

    print(f"Dla n_components = {n_components} indeks Daviesa-Bouldina wynosi: {db_score}")

# Wykres indeksu Daviesa-Bouldina dla różnych liczby składników
plt.figure(figsize=(10, 6))
plt.plot(range_n_components, davies_bouldin_scores, marker='o')
plt.xlabel('Liczba składników')
plt.ylabel('Indeks Daviesa-Bouldina')
plt.title('Indeks Daviesa-Bouldina dla różnych liczby składników w GMM')
plt.show()
# Out:
# Dla n_components = 2 indeks Daviesa-Bouldina wynosi: 2.2332696248949824
# Dla n_components = 3 indeks Daviesa-Bouldina wynosi: 1.7815594479834918
# Dla n_components = 4 indeks Daviesa-Bouldina wynosi: 2.088298312329489
# Dla n_components = 5 indeks Daviesa-Bouldina wynosi: 5.155244724899373
# Dla n_components = 6 indeks Daviesa-Bouldina wynosi: 4.431473108174629
# Dla n_components = 7 indeks Daviesa-Bouldina wynosi: 4.4735872341191785
# Dla n_components = 8 indeks Daviesa-Bouldina wynosi: 3.38037451081944
# Dla n_components = 9 indeks Daviesa-Bouldina wynosi: 3.4112015997555982
# Dla n_components = 10 indeks Daviesa-Bouldina wynosi: 3.342198521195209
# Dla n_components = 11 indeks Daviesa-Bouldina wynosi: 3.695815687657616
# Dla n_components = 12 indeks Daviesa-Bouldina wynosi: 3.800854238594523
# Dla n_components = 13 indeks Daviesa-Bouldina wynosi: 4.066940468270493
# Dla n_components = 14 indeks Daviesa-Bouldina wynosi: 3.601982510103576
# Dla n_components = 15 indeks Daviesa-Bouldina wynosi: 3.97592590775065
# Dla n_components = 16 indeks Daviesa-Bouldina wynosi: 3.4431005112947726
# Dla n_components = 17 indeks Daviesa-Bouldina wynosi: 2.7870873510761345
# Dla n_components = 18 indeks Daviesa-Bouldina wynosi: 3.9826294134278157
# Dla n_components = 19 indeks Daviesa-Bouldina wynosi: 4.144589406558001
# Dla n_components = 20 indeks Daviesa-Bouldina wynosi: 3.229192500411885
# Dla n_components = 21 indeks Daviesa-Bouldina wynosi: 4.895815640091607
# Dla n_components = 22 indeks Daviesa-Bouldina wynosi: 4.274592141941621
# Dla n_components = 23 indeks Daviesa-Bouldina wynosi: 4.20331519557458
# Dla n_components = 24 indeks Daviesa-Bouldina wynosi: 3.7797779196413317
# Dla n_components = 25 indeks Daviesa-Bouldina wynosi: 3.9773278889984245
# Dla n_components = 26 indeks Daviesa-Bouldina wynosi: 3.281251186486029
# Dla n_components = 27 indeks Daviesa-Bouldina wynosi: 3.256429647456029
# Dla n_components = 28 indeks Daviesa-Bouldina wynosi: 3.3724130389210827
# Dla n_components = 29 indeks Daviesa-Bouldina wynosi: 3.3915280006371127
# Dla n_components = 30 indeks Daviesa-Bouldina wynosi: 3.211987636685954
# Dla n_components = 31 indeks Daviesa-Bouldina wynosi: 3.196837353686649
# Dla n_components = 32 indeks Daviesa-Bouldina wynosi: 3.806178185182521
# Dla n_components = 33 indeks Daviesa-Bouldina wynosi: 3.732758902095281
# Dla n_components = 34 indeks Daviesa-Bouldina wynosi: 2.9852398774260784
# Dla n_components = 35 indeks Daviesa-Bouldina wynosi: 3.3405281772690523
# Dla n_components = 36 indeks Daviesa-Bouldina wynosi: 3.739972482092802
# Dla n_components = 37 indeks Daviesa-Bouldina wynosi: 3.537871217619729
# Dla n_components = 38 indeks Daviesa-Bouldina wynosi: 3.346592751508515
# Dla n_components = 39 indeks Daviesa-Bouldina wynosi: 3.0696048871531882

# %% [markdown]
# Ponownie 3 wypada wyjątkowo dobrze. 17 i 19 również są dobre. 27 się nei wyróznia, ale za to 34 już tak.

# %% [markdown]
# ### 4.2 model
# przetestujemy dla 17, 19, 27 klastrów, poniewaz te wartości wydają się być najlepsze. 3 nie sprawdzamy bo nie pasuje do naszego zadania.

# %%
# dla 17 klastrów
gmm_17 = GaussianMixture(n_components=17, covariance_type='full', random_state=42)
clusters_gmm_17 = gmm_17.fit_predict(df_final)

# dla 19 klastrów
gmm_19 = GaussianMixture(n_components=19, covariance_type='full', random_state=42)
clusters_gmm_19 = gmm_19.fit_predict(df_final)

# dla 27 klastrów
gmm_27 = GaussianMixture(n_components=27, covariance_type='full', random_state=42)
clusters_gmm_27 = gmm_27.fit_predict(df_final)

# %% [markdown]
# ### 4.3 wizualizacje

# %%
from sklearn.decomposition import PCA

# %%
# 17 klastrów
pca = PCA()
result = pca.fit_transform(df_final)
labels = gmm_17.fit_predict(df_final)
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = labels, palette=sns.color_palette("hls", 17))
plt.show()

# %%
# 19 klastrów
pca = PCA()
result = pca.fit_transform(df_final)
labels = gmm_19.fit_predict(df_final)
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = labels, palette=sns.color_palette("hls", 19))
plt.show()

# %%
# 27 klastrów
pca = PCA()
result = pca.fit_transform(df_final)
labels = gmm_27.fit_predict(df_final)
sns.scatterplot(x = result[:, 0], y = result[:, 1], hue = labels, palette=sns.color_palette("hls", 27))
plt.show()

# %% [markdown]
# Niestety w przypadku naszego projektu 17 lub 19 klastrów to raczej za mało dlatego mapy sprawdzimy juz tylko dla 27

# %% [markdown]
# #### Mapki

# %% [markdown]
# ##### 17 wszystkie

# %%
# przewiduje kmeans i labele ustawiam
model_instance = GaussianMixture(n_components=17, covariance_type='full', random_state=42)
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_73.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### 17 istotne

# %%
# przewiduje kmeans i labele ustawiam
model_instance = GaussianMixture(n_components=17, covariance_type='full', random_state=42)
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_85.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### 27 wszystkie

# %%
# przewiduje kmeans i labele ustawiam
model_instance = GaussianMixture(n_components=27, covariance_type='full', random_state=42)
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final)
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_101.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ##### 27 istotne

# %%
# przewiduje kmeans i labele ustawiam
model_instance = GaussianMixture(n_components=27, covariance_type='full', random_state=42)
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_87.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# #### test 90

# %%
# przewiduje kmeans i labele ustawiam
model_instance = GaussianMixture(n_components=90, covariance_type='full', random_state=42)
# Przewiduje klastry na tylko istotnych kolumnach
labels = model_instance.fit_predict(df_final.drop(['minimum_nights', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365', 'license', 'baths'], axis = 1))
df = df_final.copy()
df['labels'] = labels
df.sort_values(by=['labels'], axis = 0, inplace = True)
df['labels'] = df['labels'].astype(np.str_)
# odwracam min max scaling
df['latitude'] = df['latitude'] * (lat_max - lat_min) + lat_min
df['longitude'] = df['longitude'] * (long_max - long_min) + long_min
# plot
fig = px.scatter_mapbox(df,
                    lat="latitude", lon="longitude", color="labels",
                    zoom=10, height=800, hover_data = ['price', 'rating'])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(showlegend = True)
fig.show()
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="820"
#     src="iframe_figures/figure_88.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# ### OSTATECZNA KONKLUZJA

# %% [markdown]
# Wg nas:
#  - z perspektywy biznesowej najlepiej wypada KMeans dla 78 klastrów (tylko istotne kolumny)
#  - jednak jeśli patrzeć na to czego mieliśmy się na tym przedmiocie nauczyć najlepiej wypada GMM(27 klastrów, wszystkie kolumny) - metryki tu działają :)
